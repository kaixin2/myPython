# %% [markdown]
# # Programming in Python II - Project
# ---

# %% [markdown]
# #### For this project, you have to provide the solutions for the following questions.
#
# #### First, write the pseudocodes to clearly explain how your codes should be structured to meet the objective of the question.
# #### After which, code your answers directly into the cell after each question. Be sure to run them to ensure that your code works.
#
# #### When you have completed the assignment, proceed back to where you downloaded this file to submit your solutions!
#
# #### All the best!

# %% [markdown]
# ---

# %% [markdown]
# ## Question 1 - Advanced Python

# %% [markdown]
# ### Given the following statements containing a list with 3 tuples (each tuple describes a book title, pages, and price):

# %%
lst = [('Beginning iOS Programming', 534, 34.99), 
       ('Beginning Android Programming', 484, 29.99), 
       ('Python Machine Learning', 284, 39.99)]

# %% [markdown]
# ### Using a lambda function, write the statement to sort the list of tuples based on:

# %% [markdown]
# ### a. Book Title (alphabetical order)

# %%
#---type your answer here---

# %% [markdown]
# ### b. Number of Pages (ascending order)

# %%
#---type your answer here---

# %% [markdown]
# ### c. Price (descending order; i.e. most expensive to the cheapest)

# %%
#---type your answer here---

# %% [markdown]
# ---

# %% [markdown]
# ## Question 2 - Advanced Python

# %% [markdown]
# The National Steps Challenge™ is a physical activity initiative by the Health Promotion Board (HPB) to encourage Singapore residents to be more physically active every day, anytime and anywhere. In this challenge, one can earn either 10, 25, or 40 points depends on his/her step count for the day. The following figure shows the points reward mechanism:
#
# ![steps.JPG](attachment:steps.JPG)
#
# A Python application is to be developed for the user to keep track of his/her points. The class element diagram for the Person class is shown below:
#
# ![Person.JPG](attachment:Person.JPG)
#
#
# Your colleague has created the Person Class.

# %% [markdown]
# ```
# class Person:
#     def init(self, name, health_points):
#         self.name = name
#         self.health_points = health_points
#
#     def award_health_points(self,pt):
#         self.health_points -= pt
#         return self.health_points
#
# def add_health_points(name,health_points,steps):
#     person1 = Person(name,health_points)
#
#     if steps>10000:
#         return person1.award_health_points(40)
#     elif steps>7500:
#         return person1.award_health_points(25)
#     elif steps>5000:
#         return person1.award_health_points(10)
#     else:
#         return person1.award_health_points(0)
# ```

# %% [markdown]
# ### a) Explain the 3 errors in the above set of codes.

# %%
#---type your answer here---

# %% [markdown]
# ### b) Correct the errors.

# %%
class Person:
    #Error 1
    def __init__(self, name, health_points):
        self.name = name
        self.health_points = health_points

    def award_health_points(self,pt):
        #Error 2
        self.health_points += pt
        return self.health_points

def add_health_points(name,health_points,steps):
    person1 = Person(name,health_points)
    
    #Error 3
    if steps>=10000:
        return person1.award_health_points(40)
    elif steps>=7500:
        return person1.award_health_points(25)
    elif steps>=5000:
        return person1.award_health_points(10)
    else:
        return person1.award_health_points(0)

# %% [markdown]
# ## Question 3 - NumPy

# %% [markdown]
# Given the following code:

# %%
import numpy as np
a1 = np.round(20 * np.random.random((4,5)), 2)

# %% [markdown]
# ### a. Print out the `a1` array.

# %%
#---type your answer here---

# %% [markdown]
# ### b. Find and list out the mean of each row in the array

# %%
#---type your answer here---
#Hint: To extract the mean for each row, set the axis to 1. 0 is across row.

# %% [markdown]
# ### c. In the `a1` array, find the number that is closest to the smallest mean.
# <i>Hint: You will need to use a combination of numpy functions such as flat, abs, and argmin)</i>

# %%
#---type your answer here---

# %% [markdown]
# ---

# %% [markdown]
# ## Question 4 - Pandas

# %% [markdown]
# ### Given the following dictionary

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
             'score': [12.5, 9, 16.5, 3, 9, 20, 20, 7, 8, 19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# %% [markdown]
# ### a) Load the dictionary into a dataframe

# %%
import pandas as pd
#---type your answer here---

# %% [markdown]
# ### b) Find the highest score(s)
#
# ![PII4b.png](attachment:PII4b.png)

# %%
#---type your answer here---
#Use in-built Pandas max function
#Display the rows in the dataframe where the score value is the same as the max score.

# %% [markdown]
# ### c) Find the person who score the highest with the least attempt
#
# ![PII4c.png](attachment:PII4c.png)

# %%
#---type your answer here---
#Find the person with the minimum number of attempts
#Create the condition for highest score and least attempt (boolean mask)
#Extract all rows that meets the above conditions

# %% [markdown]
# ### d) Find the average scores

# %%
#---type your answer here---
#Use the in-built mean function
#Answer is 12.4

# %% [markdown]
# ### e) Find the students who scored above average
#
# ![a.PNG](attachment:a.PNG)

# %%
#---type your answer here---
#Extract and display all rows where the score is above the average

# %% [markdown]
# ## Question 5 - Pandas

# %% [markdown]
# For this question, you are given the following dataset - <b>Automobile_data.csv</b>.

# %%
import pandas as pd

df = pd.read_csv("Automobile_data.csv")

# %% [markdown]
# ### a. Print the first 5 rows and the last 7 rows of the dataset, like this:
# ![b.PNG](attachment:b.PNG)

# %% [markdown]
# ![c.PNG](attachment:c.PNG)

# %%
#---type your answer here---

# %%
#---type your answer here---

# %% [markdown]
# ### b. Find the company with the most expensive  car:
#
# ![d.PNG](attachment:d.PNG)

# %%
#---type your answer here---
#Get the highest price
#Display the company and price column where the price is the highest

# %% [markdown]
# ### c. Write the statements to print out each company’s most expensive car:

# %% [markdown]
# ![e.PNG](attachment:e.PNG)

# %%
#---type your answer here---
#Hint:Group all cars according to the manufacturer (groupby)
#Extract and display the highest price and body-style for each manufacturer

# %% [markdown]
# ### d. Write the statements to print out the average mileage of each car maker:
# ![f.PNG](attachment:f.PNG)

# %%
#---type your answer here---

# %% [markdown]
# ### e. For each car maker, print out the car maker’s name, and show the price of each car (from most expensive to cheapest), like this:
#
# ```
# alfa-romero
# -----------
# hatchback $16500.0
# convertible $16500.0
# convertible $13495.0
#
# audi
# ----
# wagon $18920.0
# sedan $17450.0
# sedan $15250.0
# sedan $13950.0
#
# ...
#
# mercedes-benz
# -------------
# hardtop $45400.0
# sedan $40960.0
# wagon $28248.0
# sedan $25552.0
#
# mitsubishi
# ----------
# sedan $8189.0
# sedan $6989.0
# hatchback $6189.0
# hatchback $5389.0
#
# ...
#
# volkswagen
# ----------
# sedan $9995.0
# sedan $7995.0
# sedan $7975.0
# sedan $7775.0
#
# volvo
# -----
# wagon $13415.0
# sedan $12940.0
# ```

# %%
#---type your answer here---

# %% [markdown]
# ### f. You are tasked to create a Python program to help a user quickly extract rows of interest, up to two column names and their values.
#
# ```
# Requirements:
# 1) Create a function that accepts variable number of parameters
# 2) Prompt the user to enter the first column name (e.g., company)
# 3) Prompt the user to enter the first column value (e.g., dodge)
# 4) Prompt the user to enter the second column name (e.g., num-of-cylinders) (Note: if user enters 'exit', it indicates they only wish to search by the first column name and value)
# 5) Prompt the user to enter the second column value (e.g., six) (Only applicable if user doesn't enter 'exit' in the previous input.)
# 6) Call the function you have created in part 1 to display the result.
#
# Note: In the above example, no results will be returned i.e., there are no dodge cars with six cyclinders.
# Below is an example with inputs: company, toyota, body-style, wagon
# ```
# ![g.PNG](attachment:g.PNG)

# %%
#Hint: Create a function that takes in **kwargs

# %% [markdown]
# ## <center>End of Project<center>
# ---
